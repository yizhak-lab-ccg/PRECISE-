# %%
import sys
import os

current_dir = os.getcwd()
# Add the 'modules' directory to the Python path
sys.path.append(os.path.abspath(os.path.join(current_dir, '../modules')))

import anndata as ad
import scanpy as sc
import random
from Precise import Precise
from boruta_analysis import BorutaAnalyzer
from shap_analysis import SHAPVisualizer
from reinforcement_learning import ReinforcementLearningAnalyzer
from xgboost_analysis import PredictionAnalyzer

# %% [markdown]
# #### Importing the data and Initializing a Precise object

# %%
adata = ad.read_h5ad("../examples/sample_melanoma_adata.h5ad")
adata.obs['sample'] = adata.obs['sample_name']
## Continue with preprocessing adata...
output_dir = "../results/"

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1200 × 10082
#     obs: 'ID', 'patient_number', 'time', 'sample_number', 'sample_name', 'response', 'cluster', 'T cells', 'CD4 helper T cells', 'CD8 Cytotoxic T cells', 'Regulatory T cells', 'Regulatory CD4 T cells', 'Regulatory CD8 T cells', 'Regulatory CD4 CD8 T cells', 'NKT cells', 'NK cells', 'B cells', 'Activated T cells', 'Senescence T cells', 'Terminal effector', 'Exhausted T cells', 'Stem like T cells', 'Memory T cells', 'Memory CD4 T cells', 'Memory CD8 T cells', 'Memory CD4 CD8 T cells', 'Macrophage immature', 'Macrophage mature', 'Monocyte immature', 'Monocyte mature', 'cDCs dendritic cells', 'pDCs', 'myeloid cells general immature', 'myeloid cells general mature', 'Neutrophils', 'Granolocytes', 'Double negative ', 'sample'
#     uns: 'cell_types'

# %% [markdown]
# The anndata object needs to contain in the .obs dataframe a columns with a response columns and a sample name column. These need to match the names passed to Precise in target_columns, and sample_column
# The resposne columns has to contains 0s and 1s or 'R' 'NR'.

# %%
precise = Precise(
    adata,
    model_name = 'LightGBMClassifier',
    output_dir=output_dir,
    target_column="response",  # Adjust based on your dataset
    sample_column="sample"
)

# %% [markdown]
# #### Running a leave-one-out prediction on the samples
# This result in a score for each sample, and a total AUC score. Feature importance scores are saved into the results folder.

# %%
prediction_results = precise.cv_prediction()

# %%
k_prediction_results = precise.cv_prediction(k_folds = 5, seed=1)
# Out:
# [LightGBM] [Info] Number of positive: 325, number of negative: 625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.290134 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 553713
# [LightGBM] [Info] Number of data points in the train set: 950, number of used features: 10074
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.342105 -> initscore=-0.653926
# [LightGBM] [Info] Start training from score -0.653926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 325, number of negative: 625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.336211 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 580447
# [LightGBM] [Info] Number of data points in the train set: 950, number of used features: 10077
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.342105 -> initscore=-0.653926
# [LightGBM] [Info] Start training from score -0.653926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 350, number of negative: 600
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.305572 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 543510
# [LightGBM] [Info] Number of data points in the train set: 950, number of used features: 10048
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.368421 -> initscore=-0.538997
# [LightGBM] [Info] Start training from score -0.538997
# [LightGBM] [Info] Number of positive: 350, number of negative: 625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.297770 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 574878
# [LightGBM] [Info] Number of data points in the train set: 975, number of used features: 10079
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.358974 -> initscore=-0.579818
# [LightGBM] [Info] Start training from score -0.579818
# [LightGBM] [Info] Number of positive: 350, number of negative: 625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.267717 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 583555
# [LightGBM] [Info] Number of data points in the train set: 975, number of used features: 10079
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.358974 -> initscore=-0.579818
# [LightGBM] [Info] Start training from score -0.579818

# %% [markdown]
# #### We can plot the intersection size and the top mean feature importance scores to decide on the number of most robust features

# %%
precise.create_feature_plots(200) # number of features inputed to intersection
# Out:
# Intersection plot saved to ../results\plots.
# Feature importance bar plot saved to ../results\plots\all_cells_feature_importance_barplot.png.

# %%
top_features = precise.choose_top_features(6)
top_features
# Out:
# ['TMSB10', 'IFITM2', 'GAPDH', 'DOCK8', 'HLA-B', 'GZMH']

# %% [markdown]
# ## SHAP Values Analysis

# %% [markdown]
# #### Using SHAP for gene expression anlysis, and further identification of most important genes

# %% [markdown]
# SHAP mean absolute values, and SHAP summary plots

# %%
precise.run_shap_visualizations()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.305418 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 698333
# [LightGBM] [Info] Number of data points in the train set: 1200, number of used features: 10082
# [LightGBM] [Info] Start training from score 0.354167
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ##### We can look at individual samples and interprete the model's prediction on them

# %%
precise.shap_visualizer.shap_waterfall_plot('Pre_P3')
# Out:
# [LightGBM] [Info] Number of positive: 425, number of negative: 750
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.326002 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 687431
# [LightGBM] [Info] Number of data points in the train set: 1175, number of used features: 10082
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.361702 -> initscore=-0.567984
# [LightGBM] [Info] Start training from score -0.567984
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 precise.shap_visualizer.shap_waterfall_plot('Pre_P3')
#
# File ~\OneDrive - Technion\Asaf\XGBoost_project\PRECISE-\modules\shap_analysis.py:188, in SHAPVisualizer.shap_waterfall_plot(self, sample, save_folder)
#     185     explainer = shap.Explainer(ce, df)
#     186     exp = explainer(temp.to_df()).values
# --> 188 shap.plots.waterfall(exp.mean(axis=0), show=False)
#     190 plt.tight_layout()
#     192 if save_folder:
#
# AttributeError: 'list' object has no attribute 'mean'

# %% [markdown]
# ##### Using SHAP we can find gene-gene interactions for genes of interest

# %%
precise.shap_visualizer.shap_dependence_plot('GAPDH', save_path='../results/plots/GAPDH_dependence.png')

# %% [markdown]
# Subsetting the highly variable genes reduces the running time significantly.
# The RL class ignores this, as it uses a list of genes as input, but for Boruta this is important. Note that this removes informative genes too.

# %%
precise.subset_highly_variable(2000)
# Out:
# Trying to modify attribute `.obs` of view, initializing view as actual.
# AnnData object with n_obs × n_vars = 1200 × 2000
#     obs: 'ID', 'patient_number', 'time', 'sample_number', 'sample_name', 'response', 'cluster', 'T cells', 'CD4 helper T cells', 'CD8 Cytotoxic T cells', 'Regulatory T cells', 'Regulatory CD4 T cells', 'Regulatory CD8 T cells', 'Regulatory CD4 CD8 T cells', 'NKT cells', 'NK cells', 'B cells', 'Activated T cells', 'Senescence T cells', 'Terminal effector', 'Exhausted T cells', 'Stem like T cells', 'Memory T cells', 'Memory CD4 T cells', 'Memory CD8 T cells', 'Memory CD4 CD8 T cells', 'Macrophage immature', 'Macrophage mature', 'Monocyte immature', 'Monocyte mature', 'cDCs dendritic cells', 'pDCs', 'myeloid cells general immature', 'myeloid cells general mature', 'Neutrophils', 'Granolocytes', 'Double negative ', 'sample'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'cell_types', 'hvg'

# %% [markdown]
# ## Boruta Feature Selection

# %%
boruta_results = precise.boruta_analyzer.run_boruta()
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	1985
# Iteration: 	9 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	1985
# Iteration: 	10 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	1985
# Iteration: 	11 / 100
# Confirmed: 	1
# Tentative: 	14
# Rejected: 	1985
# Iteration: 	12 / 100
# Confirmed: 	1
# Tentative: 	7
# Rejected: 	1992
# Iteration: 	13 / 100
# Confirmed: 	1
# Tentative: 	7
# Rejected: 	1992
# Iteration: 	14 / 100
# Confirmed: 	1
# Tentative: 	7
# Rejected: 	1992
# Iteration: 	15 / 100
# Confirmed: 	1
# Tentative: 	7
# Rejected: 	1992
# Iteration: 	16 / 100
# Confirmed: 	1
# Tentative: 	5
# Rejected: 	1994
# Iteration: 	17 / 100
# Confirmed: 	1
# Tentative: 	5
# Rejected: 	1994
# Iteration: 	18 / 100
# Confirmed: 	1
# Tentative: 	5
# Rejected: 	1994
# Iteration: 	19 / 100
# Confirmed: 	1
# Tentative: 	4
# Rejected: 	1995
# Iteration: 	20 / 100
# Confirmed: 	1
# Tentative: 	4
# Rejected: 	1995
# Iteration: 	21 / 100
# Confirmed: 	1
# Tentative: 	4
# Rejected: 	1995
# Iteration: 	22 / 100
# Confirmed: 	1
# Tentative: 	3
# Rejected: 	1996
# Iteration: 	23 / 100
# Confirmed: 	1
# Tentative: 	3
# Rejected: 	1996
# Iteration: 	24 / 100
# Confirmed: 	1
# Tentative: 	3
# Rejected: 	1996
# Iteration: 	25 / 100
# Confirmed: 	1
# Tentative: 	3
# Rejected: 	1996
# Iteration: 	26 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	27 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	28 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	29 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	30 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	31 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	32 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	33 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	34 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	35 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	36 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	37 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	38 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	39 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	40 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	41 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	42 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	43 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	44 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	45 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	46 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	47 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	48 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	49 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	50 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	51 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	52 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	53 / 100
# Confirmed: 	2
# Tentative: 	2
# Rejected: 	1996
# Iteration: 	54 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	55 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	56 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	57 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	58 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	59 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	60 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	61 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	62 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	63 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	64 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	65 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	66 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	67 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	68 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	69 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	70 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	71 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	72 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	73 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	74 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	75 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	76 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	77 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	78 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	79 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	80 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	81 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	82 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	83 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	84 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	85 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	86 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	87 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	88 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	89 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	90 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	91 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	92 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	93 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	94 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	95 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	96 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	97 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	98 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
# Iteration: 	99 / 100
# Confirmed: 	2
# Tentative: 	1
# Rejected: 	1997
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	2
# Tentative: 	0
# Rejected: 	1997
# Selected features saved to ../results/all_cells_boruta_chosen_features.json

# %%
_, chosen_genes_dict, _ = boruta_results
chosen_genes_dict
# Out:
# {'confirmed': ['FCGR3A', 'TGFBI'], 'tentative': []}

# %% [markdown]
# #### Boruta can also be run directly through BorutaAnalyzer for prediction purposes

# %%
# Get the unique samples
samples = list(adata.obs['sample'].unique())

# Shuffle the samples to randomize
random.shuffle(samples)

# Split into 70% train and 30% test
split_idx = int(0.7 * len(samples))
train_samples = samples[:split_idx]

# Subset the AnnData object
train_adata = adata[adata.obs['sample'].isin(train_samples)]
test_adata = adata[~adata.obs['sample'].isin(train_samples)]

# Run Boruta analysis
boruta_analyzer = BorutaAnalyzer(train_adata, verbose=False)
boruta_results = boruta_analyzer.run_boruta(test_adata=test_adata)
# Out:
# Trying to modify attribute `.obs` of view, initializing view as actual.
# Trying to modify attribute `.obs` of view, initializing view as actual.

# %%
boruta_results
# Out:
# (None,
#  {'confirmed': ['TGFBI', 'ANXA2R', 'RHOC'], 'tentative': ['DNAJB9']},
#  {'Post_P2': 0.72,
#   'Post_P3': 0.68,
#   'Post_P3_2': 0.56,
#   'Post_P5': 0.76,
#   'Post_P13': 0.84,
#   'Post_P15': 0.84,
#   'Post_P17': 1.0,
#   'Post_P18': 0.8,
#   'Post_P19': 0.92,
#   'Post_P20': 0.68,
#   'Pre_P2': 0.56,
#   'Pre_P15': 0.88,
#   'Pre_P25': 0.8,
#   'Pre_P27': 0.56,
#   'Pre_P31': 0.8})

# %% [markdown]
# ## Reinforcement Learning for Cell-Level Predictivity Scores

# %% [markdown]
# Passing a list of robust genes to RL is a must, as it reduces significantly the running time and when using a good gene subset (e.g. as extracted by LOO) it improves the distribution of predictive labels in the cohort.

# %%
# we can combine the features from boruta and the features from the LOO, and train the RL model using them
chosen_features = list(set(top_features + chosen_genes_dict['confirmed']))
rl_adata = precise.run_reinforcement_learning(chosen_features = top_features, n_iters = 50)
# Out:
# Starting RL iterations with 1200 cells and 10 features.
# Iteration 1/50
# Trying to modify attribute `.obs` of view, initializing view as actual.
# Iteration 2/50
# Iteration 3/50
# Iteration 4/50
# Iteration 5/50
# Iteration 6/50
# Iteration 7/50
# Iteration 8/50
# Iteration 9/50
# Iteration 10/50
# Iteration 11/50
# Iteration 12/50
# Iteration 13/50
# Iteration 14/50
# Iteration 15/50
# Iteration 16/50
# Iteration 17/50
# Iteration 18/50
# Iteration 19/50
# Iteration 20/50
# Iteration 21/50
# Iteration 22/50
# Iteration 23/50
# Iteration 24/50
# Iteration 25/50
# Iteration 26/50
# Iteration 27/50
# Iteration 28/50
# Iteration 29/50
# Iteration 30/50
# Iteration 31/50
# Iteration 32/50
# Iteration 33/50
# Iteration 34/50
# Iteration 35/50
# Iteration 36/50
# Iteration 37/50
# Iteration 38/50
# Iteration 39/50
# Iteration 40/50
# Iteration 41/50
# Iteration 42/50
# Iteration 43/50
# Iteration 44/50
# Iteration 45/50
# Iteration 46/50
# Iteration 47/50
# Iteration 48/50
# Iteration 49/50
# Iteration 50/50
# Results saved to ../results/

# %%
labels = precise.get_rl_distribution(49)
adata.obs['RL_labels'] = labels
# Out:
# Plot saved at ../results/plots\rl_labels_hist_49.png

# %%
sc.tl.tsne(adata)
# Out:
# WARNING: You’re trying to run this on 10082 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
group_annotations = {
    "1": "B-cells",
    "2": "Plasma cells",
    "3": "Monocytes/Macrophages",
    "4": "Dendritic cells",
    "5": "Lymphocytes",
    "6": "Exhausted CD8+ T-cells",
    "7": "Regulatory T-cells",
    "8": "Cytotoxicity (Lymphocytes)",
    "9": "Exhausted/HS CD8+ T-cells",
    "10": "Memory T-cells",
    "11": "Lymphocytes exhausted/cell-cycle"
}

adata.obs['Clusters'] = [group_annotations[cluster] for cluster in adata.obs['cluster']]
sc.pl.tsne(adata, color=['RL_labels', 'Clusters'], vmax = 4, vmin = -2)
# sc.pl.tsne(adata, color='Clusters')

# %% [markdown]
# #### Predictions can be made directly thourgh PredictionAnalyzer for more control

# %%
model = PredictionAnalyzer(adata, 'T cells', 'response', 'sample')

# %%
predictions = model.simple_prediction(adata[adata.obs['sample'].isin(train_samples)], adata[~adata.obs['sample'].isin(train_samples)])
# Out:
# Trying to modify attribute `.obs` of view, initializing view as actual.
# Starting Simple Prediction.
# Training on 825 cells from 33 samples.
# Predicting for 375 cells from 15 samples.
# Predicted scores for samples: ['Post_P2', 'Post_P3', 'Post_P3_2', 'Post_P5', 'Post_P13', 'Post_P15', 'Post_P17', 'Post_P18', 'Post_P19', 'Post_P20', 'Pre_P2', 'Pre_P15', 'Pre_P25', 'Pre_P27', 'Pre_P31']

# %%
sample_scores, features_importance = predictions
sample_scores
# Out:
# {'Post_P2': 0.28,
#  'Post_P3': 0.56,
#  'Post_P3_2': 0.76,
#  'Post_P5': 0.44,
#  'Post_P13': 0.48,
#  'Post_P15': 0.4,
#  'Post_P17': 0.64,
#  'Post_P18': 0.8,
#  'Post_P19': 0.8,
#  'Post_P20': 0.28,
#  'Pre_P2': 0.12,
#  'Pre_P15': 0.28,
#  'Pre_P25': 0.32,
#  'Pre_P27': 0.12,
#  'Pre_P31': 0.36}

# %% [markdown]
# #### The same goes for the other models

# %%
rl_analyzer = ReinforcementLearningAnalyzer(adata, celltype='T cells')
rl_analyzer.run_reinforcement_learning(n_iters=80, chosen_features=['LILRB4', 'FCER1G'],learning_rate=0.2)

# %% [markdown]
# ### Good Luck !
